# %%
import pandas as pd

# %%
import tabula

# %%
pdf_path = "union_mem_by_state_21-22.pdf"

dfs = tabula.read_pdf(pdf_path, stream=True)
# read_pdf returns list of DataFrames
print(len(dfs))
dfs[0]
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# 1
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN      Total
# 5                                               State   employed
# 6                                             Alabama      1,938
# 7                                              Alaska        293
# 8                                             Arizona      3,116
# 9                                            Arkansas      1,167
# 10                                         California     15,497
# 11                                           Colorado      2,538
# ...
