# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
df_wsa = pd.read_csv('/Users/erinmurphy/Documents/GitHub/union-viz/data/work-stoppages-annual-edit.csv')
df_wsa.head()
# Out:
#    year  works_stoppage_beginning   work_stoppage_in_effect  \
# 0  2008                         15                       16
# 1  2009                          5                        5
# 2  2010                         11                       11
# 3  2011                         19                       19
# 4  2012                         19                       21
#
#    workers_beginning_in_period  workers_in_effect_during_period
# 0                        72200                            82700
# 1                        12500                            12500
# 2                        44500                            44500
# 3                       112500                           112500
# 4                       148100                           150400

# %%
df_wsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   year                             15 non-null     int64
#  1   works_stoppage_beginning         15 non-null     int64
#  2   work_stoppage_in_effect          15 non-null     int64
#  3   workers_beginning_in_period      15 non-null     int64
#  4   workers_in_effect_during_period  15 non-null     int64
# dtypes: int64(5)
# memory usage: 728.0 bytes

# %%
# Convert year to datetime
df_wsa['year'] = pd.to_datetime(df_wsa['year'], format='%Y')
df_wsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   year                             15 non-null     datetime64[ns]
#  1   works_stoppage_beginning         15 non-null     int64
#  2   work_stoppage_in_effect          15 non-null     int64
#  3   workers_beginning_in_period      15 non-null     int64
#  4   workers_in_effect_during_period  15 non-null     int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 728.0 bytes

# %%
df_wsa.head()
# Out:
#         year  works_stoppage_beginning   work_stoppage_in_effect  \
# 0 2008-01-01                         15                       16
# 1 2009-01-01                          5                        5
# 2 2010-01-01                         11                       11
# 3 2011-01-01                         19                       19
# 4 2012-01-01                         19                       21
#
#    workers_beginning_in_period  workers_in_effect_during_period
# 0                        72200                            82700
# 1                        12500                            12500
# 2                        44500                            44500
# 3                       112500                           112500
# 4                       148100                           150400

# %%
# seaborn line plot number of workers_in_effect_during_period by year
sns.lineplot(data=df_wsa, x="year", y="workers_in_effect_during_period")
# Out:
# <AxesSubplot: xlabel='year', ylabel='workers_in_effect_during_period'>

# %%
# seaborn line plot of number of work stoppages in effect by year
sns.lineplot(data=df_wsa, x="year", y="work_stoppage_in_effect")
# Out:
# <AxesSubplot: xlabel='year', ylabel='work_stoppage_in_effect'>

# %%
# save to new csv file
df_wsa.to_csv('/Users/erinmurphy/Documents/GitHub/union-viz/data/work-stoppages-annual-clean.csv', index=False)
